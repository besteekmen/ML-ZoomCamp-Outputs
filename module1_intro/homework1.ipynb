# %% [markdown]
# ## Homework 1: Introduction
#
# This is the personal implementation of the homework 1 of [ML Zoomcamp 2026](https://github.com/DataTalksClub/machine-learning-zoomcamp).

# %% [markdown]
# #### Q1. Pandas version

# %%
import pandas as pd

print("The installed Pandas version:", pd.__version__)
# Out:
# The installed Pandas version: 3.0.5

# %% [markdown]
# #### Q2. Getting data

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Out:
# --2026-09-14 19:57:08--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 635180 (620K) [text/plain]
# Saving to: ‘car_fuel_efficiency_2026.csv’
#
# car_fuel_efficiency 100%[===================>] 620.29K  --.-KB/s    in 0.01s
#
# 2026-09-14 19:57:08 (55.6 MB/s) - ‘car_fuel_efficiency_2026.csv’ saved [635180/635180]

# %%
df = pd.read_csv("car_fuel_efficiency_2026.csv")
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# #### Q3. Records count

# %%
print("Total number of records:", len(df))
# Out:
# Total number of records: 10000

# %% [markdown]
# #### Q4. Fuel types

# %%
print(f"Total number of fuel types: {df["fuel_type"].nunique()} \n")
print(df["fuel_type"].value_counts())
# Out:
# Total number of fuel types: 3
#
# fuel_type
# Gasoline    6913
# Diesel      2053
# Hybrid      1034
# Name: count, dtype: int64

# %% [markdown]
# #### Q5. Missing values

# %%
print(f"Total number of columns with missing values: {(df.isnull().sum() > 0).sum()} \n")
print(df.isnull().sum())
# Out:
# Total number of columns with missing values: 2
#
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# #### Q6. Max fuel efficiency

# %%
print(f"The maximum fuel efficiency of cars from Asia: {df[df["origin"] == "Asia"].fuel_efficiency_mpg.max():.2f}")
# Out:
# The maximum fuel efficiency of cars from Asia: 41.20

# %% [markdown]
# #### Q7. Median value of horsepower

# %%
med_old = df["horsepower"].median()
print("Old median:", med_old)

mode = df["horsepower"].mode()[0]
print("Most frequent horsepower:", mode)

df["horsepower"] = df["horsepower"].fillna(mode)
med_new = df["horsepower"].median()
print("New median:", med_new)

if med_new < med_old:
    print("Yes, it decreased")
elif med_new > med_old:
    print("Yes, it increased")
else:
    print("No")
# Out:
# Old median: 254.0
# Most frequent horsepower: 252.0
# New median: 252.0
# Yes, it decreased

# %% [markdown]
# #### Q8. Sum of weights

# %%
df[df["origin"] == "Asia"][["vehicle_weight", "model_year"]].head(7).values
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
import numpy as np

X = df[df["origin"] == "Asia"][["vehicle_weight", "model_year"]].head(7).values
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
w = XTX_inv.dot(X.T).dot(y)
print("Sum of all the elements of the result:", w.sum())
# Out:
# Sum of all the elements of the result: 0.36919696904925486
